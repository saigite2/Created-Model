# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
#importing data
df = pd.read_csv(r"D:\data\ADANIPORTS.csv", index_col = "Date")

# %%
#understand the data
df.head()
# Out:
#                 Symbol Series  Prev Close    Open     High    Low   Last  \
# Date
# 2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.0  959.0
# 2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.0  885.0
# 2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.0  887.0
# 2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.0  929.0
# 2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.0  980.0
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2007-11-27  962.90  984.72  27294366  2.687719e+15     NaN
# 2007-11-28  893.90  941.38   4581338  4.312765e+14     NaN
# 2007-11-29  884.20  888.09   5124121  4.550658e+14     NaN
# 2007-11-30  921.55  929.17   4609762  4.283257e+14     NaN
# 2007-12-03  969.30  965.65   2977470  2.875200e+14     NaN
#
#             Deliverable Volume  %Deliverble
# Date
# 2007-11-27             9859619       0.3612
# 2007-11-28             1453278       0.3172
# ...

# %%
df.tail()
# Out:
#                 Symbol Series  Prev Close   Open    High     Low   Last  \
# Date
# 2021-04-26  ADANIPORTS     EQ      725.35  733.0  739.65  728.90  729.2
# 2021-04-27  ADANIPORTS     EQ      730.75  735.0  757.50  727.35  748.6
# 2021-04-28  ADANIPORTS     EQ      749.15  755.0  760.00  741.10  743.4
# 2021-04-29  ADANIPORTS     EQ      746.25  753.2  765.85  743.40  746.4
# 2021-04-30  ADANIPORTS     EQ      746.75  739.0  759.45  724.50  726.4
#
#              Close    VWAP    Volume      Turnover    Trades  \
# Date
# 2021-04-26  730.75  733.25   9390549  6.885658e+14  116457.0
# 2021-04-27  749.15  747.67  20573107  1.538191e+15  236896.0
# 2021-04-28  746.25  751.02  11156977  8.379106e+14  130847.0
# 2021-04-29  746.75  753.06  13851910  1.043139e+15  153293.0
# 2021-04-30  730.05  743.35  12600934  9.366911e+14  132141.0
#
#             Deliverable Volume  %Deliverble
# Date
# 2021-04-26              838079       0.0892
# 2021-04-27             1779639       0.0865
# ...

# %%
df.shape
# Out:
# (3322, 14)

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  3322.000000  3322.000000  3322.000000  3322.000000  3322.000000
# mean    344.114314   344.763019   351.608007   337.531969   344.239539
# std     192.936882   193.619992   198.617808   188.676614   193.187813
# min     108.000000   108.000000   110.450000   105.650000   108.000000
# 25%     164.312500   164.850000   168.000000   161.600000   164.075000
# 50%     324.700000   325.750000   331.275000   319.850000   325.000000
# 75%     400.912500   401.000000   407.187500   395.000000   400.912500
# max    1307.450000  1310.250000  1324.000000  1270.000000  1308.000000
#
#              Close         VWAP        Volume      Turnover        Trades  \
# count  3322.000000  3322.000000  3.322000e+03  3.322000e+03  2.456000e+03
# mean    344.201626   344.853182  2.954564e+06  1.070144e+14  4.492259e+04
# std     193.045886   193.841305  4.104227e+06  2.625564e+14  5.023124e+04
# ...

# %%
#choose data only
df = df["2018-04-30":"2021-04-30"]

# %%
#market open before 6 month's
df.head(1)
# Out:
#                 Symbol Series  Prev Close   Open   High    Low    Last  Close  \
# Date
# 2018-04-30  ADANIPORTS     EQ      402.45  405.8  411.3  402.4  406.25  407.3
#
#               VWAP   Volume      Turnover   Trades  Deliverable Volume  \
# Date
# 2018-04-30  406.55  2264144  9.204876e+13  44313.0              925149
#
#             %Deliverble
# Date
# 2018-04-30       0.4086

# %%
#market open after 6 month's
df.tail(1)
# Out:
#                 Symbol Series  Prev Close   Open    High    Low   Last  \
# Date
# 2021-04-30  ADANIPORTS     EQ      746.75  739.0  759.45  724.5  726.4
#
#              Close    VWAP    Volume      Turnover    Trades  \
# Date
# 2021-04-30  730.05  743.35  12600934  9.366911e+14  132141.0
#
#             Deliverable Volume  %Deliverble
# Date
# 2021-04-30             3514692       0.2789

# %%
#PRICE RANGE OF MARKET IN LAST 6 MONTHS
print("OPEN MAX:-", df1['Open'].max(), "OPEN MIN:-", df1['Open'].min())
print("CLOSE MAX:-", df1['Close'].max(), "CLOSE MAX:-", df1['Close'].max())
# Out:
# OPEN MAX:- 857.0 OPEN MIN:- 216.0
# CLOSE MAX:- 835.55 CLOSE MAX:- 835.55

# %%
#shape of data
df.shape
# Out:
# (743, 14)

# %%
#Dealing with columns
df.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Symbol                  1
# Series                  1
# Prev Close            639
# Open                  580
# High                  634
# Low                   645
# Last                  624
# Close                 640
# VWAP                  724
# Volume                743
# Turnover              743
# Trades                738
# Deliverable Volume    743
# %Deliverble           696
# dtype: int64

# %%
#cleaning of data
df.isnull().sum()
# Out:
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
#create new clean dataset
df1 = df.drop(['Series', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
       '%Deliverble'], axis = 1)

# %%
#cleaned data set
df1.head()
# Out:
#                 Symbol  Prev Close    Open   High     Low    Last   Close
# Date
# 2018-04-30  ADANIPORTS      402.45  405.80  411.3  402.40  406.25  407.30
# 2018-05-02  ADANIPORTS      407.30  408.00  411.2  397.30  402.70  401.10
# 2018-05-03  ADANIPORTS      401.10  399.70  406.3  393.55  396.40  397.00
# 2018-05-04  ADANIPORTS      397.00  401.95  409.6  391.30  408.00  408.25
# 2018-05-07  ADANIPORTS      408.25  410.00  414.3  405.95  412.80  412.40

# %%
#A heat map is a two-dimensional representation of data in which values are represented by colors
sns.heatmap(corelation, xticklabels = corelation.columns, yticklabels = corelation.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df1)

# %%
#relation plot of two variable x ='Open', y ='Close'
sns.relplot(x ='Open', y ='Close', hue = 'Symbol', data = df1)

# %%
sns.histplot(df1['Open'])
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Count'>

# %%
sns.distplot(df1['Close'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Close', ylabel='Density'>

# %%
sns.catplot(x='Open', kind='box', data=df1)

# %%
sns.stripplot(df1['Open'], df1['Close'], jitter = True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
#Data conversion
#know the data type
print(df1.dtypes)
# Out:
# Symbol         object
# Prev Close    float64
# Open          float64
# High          float64
# Low           float64
# Last          float64
# Close         float64
# dtype: object

# %%
#The default return dtype is float64 or int64 depending on the data supplied.
#Use the downcast parameter to obtain other dtypes.
df1[['Open']] = df1[['Open']].apply(pd.to_numeric, errors='coerce')

# %%
# looking for outlier
# relationship analysis
cor = df1.corr()

# %%
#Correlation with respect to Open variable and filtering out variables with less correlation.
columns = cor[cor['Open']>0]['Open']
columns_list = columns.index
columns_list
# Out:
# Index(['Prev Close', 'Open', 'High', 'Low', 'Last', 'Close'], dtype='object')

# %%
#Converting that into dataframe
df1 = pd.DataFrame(df1)

# %%
sns.pairplot(df1[df1['Open'] > 0], 
             vars = ['Open', 'High', 'Close'], diag_kind = 'hist', 
             plot_kws = {'alpha': 0.7, 's': 10, 'edgecolor': 'r'},
             size = 3);
# Title 
plt.suptitle('Stock variation', 
             size = 20);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#EDA 2 Start.....................................................>>>>>>>>>>>>>>>
sns.distplot(df1['Open'], kde=False, rug=True)
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(df1['Open'], df1['Close'])
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pointplot(df1['Open'], df1['Close'], hue=df1['Symbol'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
#kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }
sns.jointplot(df1['Open'], df1['Open'], kind = 'hex')
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#strip plot is a graphical data anlysis technique for summarizing a univariate data set.
sns.stripplot(df1['Open'], df1['Open'], jitter = True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open', ylabel='Open'>

# %%
# swarm plot is another way of plotting the distribution of an attribute or the joint distribution of a couple of attributes.
sns.swarmplot(df1['Open'], df1['Close'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 80.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.boxplot(df1['Open'], df1['Close'], hue=df1['Symbol'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
sns.barplot(df1['Open'], df1['Close'], hue=df1['Symbol'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
sns.countplot(df1['Open'], hue=df1['Symbol'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open', ylabel='count'>

# %%
sns.pointplot(df1['Open'], df1['Close'], hue=df1['Symbol'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open', ylabel='Close'>

# %%
sns.lmplot(x='Open', y ='Close',data=df1, hue='Symbol')
